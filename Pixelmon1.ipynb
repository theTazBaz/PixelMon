# %% [markdown]
# <a href="https://colab.research.google.com/github/rzil-1/PixelMon/blob/main/Pixelmon1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random
import json
from gym import Env
from gym.spaces import Discrete, Box

# ===============================
# Environment with Pokémon Switching
# ===============================
class EnhancedPokemonBattleEnv(Env):
    def __init__(self, pokemon_data_path="/content/pokemon_trial.json"):
        super(EnhancedPokemonBattleEnv, self).__init__()

        # Load Pokémon data (each with type and moves)
        self.pokemon_data = self.load_pokemon_data(pokemon_data_path)

        # Type effectiveness chart (customize as needed)
        self.type_chart = {
            "Fire": {"Grass": 2.0, "Water": 0.5, "Fire": 0.5},
            "Water": {"Fire": 2.0, "Grass": 0.5, "Water": 0.5},
            "Grass": {"Water": 2.0, "Fire": 0.5, "Grass": 0.5},
            "Electric": {"Water": 2.0, "Grass": 0.5, "Electric": 0.5},
            "Normal": {},
            "Dark": {"Psychic": 2.0, "Fighting": 0.5},
            "Dragon": {"Dragon": 2.0}
            # Add other types as needed.
        }

        # Action space: 0-3 use a move; 4-7 switch to bench slot (0-indexed)
        self.action_space = Discrete(8)
        # Observation: [agent_active_hp, opponent_active_hp, last_agent_damage, last_opponent_damage, agent_remaining]
        self.observation_space = Box(
            low=np.array([0, 0, 0, 0, 1]),
            high=np.array([500, 500, 100, 100, 4]),
            dtype=np.float32
        )

        self.max_steps = 30
        self.reset()

    def load_pokemon_data(self, path):
        with open(path, 'r') as f:
            return json.load(f)

    def get_type_multiplier(self, move_type, target_type):
        return self.type_chart.get(move_type, {}).get(target_type, 1.0)

    def reset(self):
        self.steps = 0
        self.last_agent_damage = 0
        self.last_opponent_damage = 0

        # --- For the Agent ---
        # Select 4 random Pokémon for the agent.
        self.agent_bench = []
        agent_keys = random.sample(list(self.pokemon_data.keys()), 4)
        for key in agent_keys:
            pkmn = {
                "name": key,
                "type": self.pokemon_data[key]["type"],
                "moves": list(self.pokemon_data[key]["moves"].values()),
                "hp": 500
            }
            self.agent_bench.append(pkmn)
        # Choose one active Pokémon (randomly)
        self.agent_active_idx = random.randint(0, 3)

        # --- For the Opponent ---
        # Select 4 random Pokémon for the opponent.
        self.opponent_bench = []
        opponent_keys = random.sample(list(self.pokemon_data.keys()), 4)
        for key in opponent_keys:
            pkmn = {
                "name": key,
                "type": self.pokemon_data[key]["type"],
                "moves": list(self.pokemon_data[key]["moves"].values()),
                "hp": 500
            }
            self.opponent_bench.append(pkmn)
        # Choose one active Pokémon for the opponent (randomly)
        self.opponent_active_idx = random.randint(0, 3)

        return self._get_state()

    def _get_state(self):
        # Count how many agent Pokémon are still alive (hp > 0)
        agent_remaining = sum(1 for p in self.agent_bench if p["hp"] > 0)
        return np.array([
            self.agent_bench[self.agent_active_idx]["hp"],
            self.opponent_bench[self.opponent_active_idx]["hp"],
            self.last_agent_damage,
            self.last_opponent_damage,
            agent_remaining
        ], dtype=np.float32)

    def step(self, action):
        self.steps += 1
        reward = 0

        # --- Agent Turn ---
        # If action is a switching action:
        if action >= 4:
            new_idx = action - 4
            # If already active, do nothing (and impose a small penalty)
            if new_idx == self.agent_active_idx:
                reward -= 2  # penalty for wasted switch
            else:
                # Switch active Pokémon (if the target is still alive)
                if self.agent_bench[new_idx]["hp"] > 0:
                    self.agent_active_idx = new_idx
                    reward -= 1  # small penalty to discourage unnecessary switches
                else:
                    # If the chosen Pokémon is fainted, no effect (and penalty)
                    reward -= 5
            # When switching, no attack is performed.
            agent_damage = 0
        else:
            # Move action: use selected move from active Pokémon.
            active_agent = self.agent_bench[self.agent_active_idx]
            # If the active Pokémon is fainted, force a switch (no move action)
            if active_agent["hp"] <= 0:
                agent_damage = 0
            else:
                # Ensure move index is in range (the Pokémon has 4 moves)
                move_idx = action
                if move_idx >= len(active_agent["moves"]):
                    move_idx = 0  # fallback
                move = active_agent["moves"][move_idx]
                base_damage = move["damage"]
                multiplier = self.get_type_multiplier(move["type"], self.opponent_bench[self.opponent_active_idx]["type"])
                agent_damage = base_damage * multiplier
                # Subtract damage from opponent's active Pokémon
                self.opponent_bench[self.opponent_active_idx]["hp"] -= agent_damage

        self.last_agent_damage = agent_damage

        # --- Opponent Turn ---
        # Check: if opponent active is fainted, force a switch.
        if self.opponent_bench[self.opponent_active_idx]["hp"] <= 0:
            available = [i for i, p in enumerate(self.opponent_bench) if p["hp"] > 0]
            if available:
                self.opponent_active_idx = random.choice(available)
        # Now, if an opponent is available, it attacks.
        if self.opponent_bench[self.opponent_active_idx]["hp"] > 0:
            opp_active = self.opponent_bench[self.opponent_active_idx]
            opp_move = random.choice(opp_active["moves"])
            opp_base_damage = opp_move["damage"]
            opp_multiplier = self.get_type_multiplier(opp_move["type"], self.agent_bench[self.agent_active_idx]["type"])
            opponent_damage = opp_base_damage * opp_multiplier
            self.agent_bench[self.agent_active_idx]["hp"] -= opponent_damage
        else:
            opponent_damage = 0

        self.last_opponent_damage = opponent_damage

        # If the agent's active Pokémon fainted due to the opponent's attack, force a switch:
        if self.agent_bench[self.agent_active_idx]["hp"] <= 0:
            available = [i for i, p in enumerate(self.agent_bench) if p["hp"] > 0]
            if available:
                self.agent_active_idx = random.choice(available)

        # --- Reward Calculation ---
        # Base reward: reward damage dealt
        reward += 5 * agent_damage
        # Bonus if agent's active HP is higher than opponent's
        hp_diff = self.agent_bench[self.agent_active_idx]["hp"] - self.opponent_bench[self.opponent_active_idx]["hp"]
        reward += 0.1 * (hp_diff / 500)
        # Penalize if no damage is done when an attack was attempted.
        if action < 4 and agent_damage == 0:
            reward -= 5

        # Outcome rewards:
        # If all opponent Pokémon have fainted, win bonus.
        if all(p["hp"] <= 0 for p in self.opponent_bench):
            hp_bonus = self.agent_bench[self.agent_active_idx]["hp"] / 500
            reward += 50 + (20 * hp_bonus)
        # If all agent Pokémon fainted, lose penalty.
        if all(p["hp"] <= 0 for p in self.agent_bench):
            reward -= 50
        # If max steps reached, reward or penalty based on HP advantage.
        if self.steps >= self.max_steps:
            agent_total = sum(p["hp"] for p in self.agent_bench if p["hp"] > 0)
            opp_total = sum(p["hp"] for p in self.opponent_bench if p["hp"] > 0)
            if agent_total > opp_total:
                reward += 10 * (agent_total - opp_total) / 500
            else:
                reward -= 10

        # Determine if battle is over.
        done = (all(p["hp"] <= 0 for p in self.agent_bench) or
                all(p["hp"] <= 0 for p in self.opponent_bench) or
                self.steps >= self.max_steps)

        return self._get_state(), reward, done, {}

    def render(self, mode='human'):
        print(f"Step: {self.steps}")
        print(f"Agent Active: {self.agent_bench[self.agent_active_idx]['name']} [{self.agent_bench[self.agent_active_idx]['hp']:.1f} HP]")
        print(f"Opponent Active: {self.opponent_bench[self.opponent_active_idx]['name']} [{self.opponent_bench[self.opponent_active_idx]['hp']:.1f} HP]")
        print("-" * 40)


# ===============================
# State Discretization Function (for Q-Learning)
# ===============================
def discretize_state(state):
    """
    State vector:
      [agent_active_hp, opponent_active_hp, last_agent_damage, last_opponent_damage, agent_remaining]

    We use predefined bins for HP and damage; agent_remaining is an integer (1 to 4).
    """
    # Define bins for HP and damage
    hp_bins = np.array([0, 100, 200, 300, 400, 500])
    damage_bins = np.array([0, 20, 40, 60, 80, 100])

    # Discretize agent active HP: cap maximum index at len(hp_bins)-3 so the max index is 3.
    hp1_idx = np.digitize(state[0], hp_bins) - 1
    hp1_idx = min(hp1_idx, len(hp_bins) - 3)

    # Discretize opponent active HP
    hp2_idx = np.digitize(state[1], hp_bins) - 1
    hp2_idx = min(hp2_idx, len(hp_bins) - 3)

    # Discretize last agent damage
    dmg1_idx = np.digitize(state[2], damage_bins) - 1
    dmg1_idx = min(dmg1_idx, len(damage_bins) - 3)

    # Discretize last opponent damage
    dmg2_idx = np.digitize(state[3], damage_bins) - 1
    dmg2_idx = min(dmg2_idx, len(damage_bins) - 3)

    # Agent remaining: values from 1 to 4 → subtract 1 to get an index from 0 to 3.
    remain_idx = int(state[4]) - 1
    remain_idx = min(max(remain_idx, 0), 3)

    return (hp1_idx, hp2_idx, dmg1_idx, dmg2_idx, remain_idx)


# ===============================
# Q-Learning Training Parameters
# ===============================
# For our discretization:
hp_bins_count = 4       # valid indices 0 to 3
damage_bins_count = 4   # valid indices 0 to 3
remain_bins_count = 4   # for agent_remaining (1-4 mapped to 0-3)

num_actions = 8  # 4 moves + 4 switching actions
epsilon = 1.0
epsilon_min = 0.05
epsilon_decay = 0.9997
alpha = 0.1
gamma = 0.95

# Q-table shape: (hp1, hp2, dmg1, dmg2, remain, action)
q_table = np.zeros((hp_bins_count, hp_bins_count, damage_bins_count, damage_bins_count, remain_bins_count, num_actions))

env = EnhancedPokemonBattleEnv("/content/pokemon_trial.json")
num_episodes = 25000
recent_rewards = []

for episode in range(num_episodes):
    state = env.reset()
    total_reward = 0
    done = False

    while not done:
        state_idx = discretize_state(state)

        # Epsilon-greedy action selection.
        if random.uniform(0, 1) < epsilon:
            action = env.action_space.sample()
        else:
            action = np.argmax(q_table[state_idx])

        next_state, reward, done, _ = env.step(action)
        next_state_idx = discretize_state(next_state)

        # Q-learning update.
        old_value = q_table[state_idx][action]
        next_max = np.max(q_table[next_state_idx])
        new_value = (1 - alpha) * old_value + alpha * (reward + gamma * next_max)
        q_table[state_idx][action] = new_value

        state = next_state
        total_reward += reward

    recent_rewards.append(total_reward)
    if len(recent_rewards) > 100:
        recent_rewards.pop(0)

    epsilon = max(epsilon_min, epsilon * epsilon_decay)

    if (episode + 1) % 1000 == 0:
        avg_reward = np.mean(recent_rewards)
        print(f"Episode: {episode + 1}, Avg Reward: {avg_reward:.2f}, Epsilon: {epsilon:.3f}")

# ===============================
# Test the Trained Agent
# ===============================
test_episodes = 10
test_wins = 0

for episode in range(test_episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        state_idx = discretize_state(state)
        action = np.argmax(q_table[state_idx])
        state, reward, done, _ = env.step(action)
        total_reward += reward
        env.render()

    if reward > 0:
        test_wins += 1
    print(f"Test Episode {episode + 1} finished with total reward: {total_reward:.2f}")

print(f"Test Win Rate: {(test_wins/test_episodes)*100:.2f}%")
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Episode: 1000, Avg Reward: 4309.16, Epsilon: 0.741
# Episode: 2000, Avg Reward: 5038.09, Epsilon: 0.549
# Episode: 3000, Avg Reward: 5561.64, Epsilon: 0.407
# Episode: 4000, Avg Reward: 6014.54, Epsilon: 0.301
# Episode: 5000, Avg Reward: 6219.21, Epsilon: 0.223
# Episode: 6000, Avg Reward: 6537.82, Epsilon: 0.165
# Episode: 7000, Avg Reward: 6689.78, Epsilon: 0.122
# Episode: 8000, Avg Reward: 6953.07, Epsilon: 0.091
# Episode: 9000, Avg Reward: 6773.59, Epsilon: 0.067
# Episode: 10000, Avg Reward: 6998.76, Epsilon: 0.050
# Episode: 11000, Avg Reward: 6799.52, Epsilon: 0.050
# Episode: 12000, Avg Reward: 6799.23, Epsilon: 0.050
# Episode: 13000, Avg Reward: 7293.25, Epsilon: 0.050
# Episode: 14000, Avg Reward: 6850.44, Epsilon: 0.050
# Episode: 15000, Avg Reward: 6812.73, Epsilon: 0.050
# Episode: 16000, Avg Reward: 6813.41, Epsilon: 0.050
# Episode: 17000, Avg Reward: 7019.67, Epsilon: 0.050
# Episode: 18000, Avg Reward: 6933.10, Epsilon: 0.050
# Episode: 19000, Avg Reward: 6729.47, Epsilon: 0.050
# Episode: 20000, Avg Reward: 6884.63, Epsilon: 0.050
# Episode: 21000, Avg Reward: 6855.24, Epsilon: 0.050
# Episode: 22000, Avg Reward: 7140.28, Epsilon: 0.050
# Episode: 23000, Avg Reward: 7190.34, Epsilon: 0.050
# Episode: 24000, Avg Reward: 6923.36, Epsilon: 0.050
# Episode: 25000, Avg Reward: 7134.39, Epsilon: 0.050
# Step: 1
# Agent Active: Sandshrew [425.0 HP]
# Opponent Active: Geodude [450.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Sandshrew [340.0 HP]
# Opponent Active: Geodude [410.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Sandshrew [265.0 HP]
# Opponent Active: Geodude [370.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Sandshrew [240.0 HP]
# Opponent Active: Geodude [330.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Sandshrew [180.0 HP]
# Opponent Active: Geodude [280.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Sandshrew [120.0 HP]
# Opponent Active: Geodude [230.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Sandshrew [70.0 HP]
# Opponent Active: Geodude [180.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Meowth [500.0 HP]
# Opponent Active: Geodude [130.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Meowth [400.0 HP]
# Opponent Active: Geodude [90.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Meowth [325.0 HP]
# Opponent Active: Geodude [50.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Meowth [250.0 HP]
# Opponent Active: Geodude [10.0 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Meowth [210.0 HP]
# Opponent Active: Vulpix [500.0 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Meowth [115.0 HP]
# Opponent Active: Vulpix [460.0 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Meowth [15.0 HP]
# Opponent Active: Vulpix [420.0 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Diglett [500.0 HP]
# Opponent Active: Vulpix [360.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Diglett [410.0 HP]
# Opponent Active: Vulpix [340.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Diglett [260.0 HP]
# Opponent Active: Vulpix [320.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Diglett [165.0 HP]
# Opponent Active: Vulpix [300.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Diglett [70.0 HP]
# Opponent Active: Vulpix [270.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Magnemite [500.0 HP]
# Opponent Active: Vulpix [210.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Magnemite [420.0 HP]
# Opponent Active: Vulpix [155.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Magnemite [385.0 HP]
# Opponent Active: Vulpix [65.0 HP]
# ----------------------------------------
# Step: 23
# Agent Active: Magnemite [345.0 HP]
# Opponent Active: Vulpix [25.0 HP]
# ----------------------------------------
# Step: 24
# Agent Active: Magnemite [245.0 HP]
# Opponent Active: Psyduck [500.0 HP]
# ----------------------------------------
# Step: 25
# Agent Active: Magnemite [165.0 HP]
# Opponent Active: Psyduck [410.0 HP]
# ----------------------------------------
# Step: 26
# Agent Active: Magnemite [120.0 HP]
# Opponent Active: Psyduck [330.0 HP]
# ----------------------------------------
# Step: 27
# Agent Active: Magnemite [10.0 HP]
# Opponent Active: Psyduck [250.0 HP]
# ----------------------------------------
# Step: 28
# Agent Active: Magnemite [-85.0 HP]
# Opponent Active: Psyduck [160.0 HP]
# ----------------------------------------
# Test Episode 1 finished with total reward: 7049.87
# Step: 1
# Agent Active: Vulpix [410.0 HP]
# Opponent Active: Magikarp [450.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Vulpix [362.5 HP]
# Opponent Active: Magikarp [420.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Sentret [405.0 HP]
# Opponent Active: Magikarp [420.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Sentret [295.0 HP]
# Opponent Active: Magikarp [402.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Sentret [255.0 HP]
# Opponent Active: Magikarp [384.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Magnemite [415.0 HP]
# Opponent Active: Magikarp [384.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Magnemite [315.0 HP]
# Opponent Active: Magikarp [294.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Magnemite [205.0 HP]
# Opponent Active: Magikarp [204.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Magnemite [55.0 HP]
# Opponent Active: Magikarp [94.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Sentret [255.0 HP]
# Opponent Active: Magikarp [4.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Sentret [165.0 HP]
# Opponent Active: Poliwag [500.0 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Sentret [100.0 HP]
# Opponent Active: Poliwag [482.0 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Vulpix [362.5 HP]
# Opponent Active: Poliwag [442.0 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Vulpix [362.5 HP]
# Opponent Active: Poliwag [412.0 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Squirtle [445.0 HP]
# Opponent Active: Poliwag [412.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Squirtle [380.0 HP]
# Opponent Active: Poliwag [362.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Squirtle [360.0 HP]
# Opponent Active: Poliwag [312.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Squirtle [180.0 HP]
# Opponent Active: Poliwag [292.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Squirtle [140.0 HP]
# Opponent Active: Poliwag [232.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Squirtle [107.5 HP]
# Opponent Active: Poliwag [212.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Squirtle [37.5 HP]
# Opponent Active: Poliwag [212.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Vulpix [362.5 HP]
# Opponent Active: Poliwag [192.0 HP]
# ----------------------------------------
# Step: 23
# Agent Active: Vulpix [232.5 HP]
# Opponent Active: Poliwag [162.0 HP]
# ----------------------------------------
# Step: 24
# Agent Active: Vulpix [152.5 HP]
# Opponent Active: Poliwag [112.0 HP]
# ----------------------------------------
# Step: 25
# Agent Active: Vulpix [72.5 HP]
# Opponent Active: Poliwag [62.0 HP]
# ----------------------------------------
# Step: 26
# Agent Active: Vulpix [-27.5 HP]
# Opponent Active: Poliwag [22.0 HP]
# ----------------------------------------
# Test Episode 2 finished with total reward: 5011.79
# Step: 1
# Agent Active: Shinx [440.0 HP]
# Opponent Active: Diglett [435.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Shinx [350.0 HP]
# Opponent Active: Diglett [370.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Shinx [260.0 HP]
# Opponent Active: Diglett [305.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Shinx [170.0 HP]
# Opponent Active: Diglett [240.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Shinx [110.0 HP]
# Opponent Active: Diglett [150.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Magmar [500.0 HP]
# Opponent Active: Diglett [85.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Magmar [480.0 HP]
# Opponent Active: Diglett [10.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Magmar [320.0 HP]
# Opponent Active: Magikarp [500.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Magmar [170.0 HP]
# Opponent Active: Magikarp [455.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Magmar [80.0 HP]
# Opponent Active: Magikarp [410.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Chikorita [500.0 HP]
# Opponent Active: Magikarp [372.5 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Chikorita [430.0 HP]
# Opponent Active: Magikarp [262.5 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Chikorita [210.0 HP]
# Opponent Active: Magikarp [152.5 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Chikorita [60.0 HP]
# Opponent Active: Magikarp [62.5 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Chikorita [15.0 HP]
# Opponent Active: Magikarp [22.5 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Growlithe [500.0 HP]
# Opponent Active: Magnemite [500.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Growlithe [250.0 HP]
# Opponent Active: Magnemite [435.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Growlithe [170.0 HP]
# Opponent Active: Magnemite [375.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Growlithe [170.0 HP]
# Opponent Active: Magnemite [335.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Growlithe [80.0 HP]
# Opponent Active: Magnemite [275.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Growlithe [0.0 HP]
# Opponent Active: Magnemite [210.0 HP]
# ----------------------------------------
# Test Episode 3 finished with total reward: 6812.36
# Step: 1
# Agent Active: Poliwag [420.0 HP]
# Opponent Active: Vulpix [415.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Poliwag [355.0 HP]
# Opponent Active: Vulpix [330.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Poliwag [335.0 HP]
# Opponent Active: Vulpix [245.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Poliwag [280.0 HP]
# Opponent Active: Vulpix [230.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Poliwag [200.0 HP]
# Opponent Active: Vulpix [215.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Poliwag [155.0 HP]
# Opponent Active: Vulpix [130.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Poliwag [75.0 HP]
# Opponent Active: Vulpix [50.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Poliwag [15.0 HP]
# Opponent Active: Pidgey [500.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Electrike [500.0 HP]
# Opponent Active: Pidgey [415.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Electrike [460.0 HP]
# Opponent Active: Pidgey [350.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Electrike [390.0 HP]
# Opponent Active: Pidgey [310.0 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Electrike [350.0 HP]
# Opponent Active: Pidgey [245.0 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Electrike [200.0 HP]
# Opponent Active: Pidgey [185.0 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Electrike [160.0 HP]
# Opponent Active: Pidgey [125.0 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Electrike [100.0 HP]
# Opponent Active: Pidgey [60.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Electrike [50.0 HP]
# Opponent Active: Sandshrew [500.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Cubone [500.0 HP]
# Opponent Active: Sandshrew [460.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Cubone [425.0 HP]
# Opponent Active: Sandshrew [410.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Cubone [395.0 HP]
# Opponent Active: Sandshrew [360.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Cubone [295.0 HP]
# Opponent Active: Sandshrew [290.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Cubone [280.0 HP]
# Opponent Active: Sandshrew [240.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Cubone [210.0 HP]
# Opponent Active: Sandshrew [170.0 HP]
# ----------------------------------------
# Step: 23
# Agent Active: Cubone [110.0 HP]
# Opponent Active: Sandshrew [150.0 HP]
# ----------------------------------------
# Step: 24
# Agent Active: Cubone [35.0 HP]
# Opponent Active: Sandshrew [85.0 HP]
# ----------------------------------------
# Step: 25
# Agent Active: Meowth [500.0 HP]
# Opponent Active: Sandshrew [20.0 HP]
# ----------------------------------------
# Step: 26
# Agent Active: Meowth [460.0 HP]
# Opponent Active: Sentret [500.0 HP]
# ----------------------------------------
# Step: 27
# Agent Active: Meowth [390.0 HP]
# Opponent Active: Sentret [460.0 HP]
# ----------------------------------------
# Step: 28
# Agent Active: Meowth [330.0 HP]
# Opponent Active: Sentret [400.0 HP]
# ----------------------------------------
# Step: 29
# Agent Active: Meowth [270.0 HP]
# Opponent Active: Sentret [340.0 HP]
# ----------------------------------------
# Step: 30
# Agent Active: Meowth [230.0 HP]
# Opponent Active: Sentret [280.0 HP]
# ----------------------------------------
# Test Episode 4 finished with total reward: 8865.00
# Step: 1
# Agent Active: Squirtle [415.0 HP]
# Opponent Active: Poliwag [440.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Squirtle [360.0 HP]
# Opponent Active: Poliwag [380.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Squirtle [290.0 HP]
# Opponent Active: Poliwag [330.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Squirtle [270.0 HP]
# Opponent Active: Poliwag [280.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Squirtle [185.0 HP]
# Opponent Active: Poliwag [230.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Squirtle [145.0 HP]
# Opponent Active: Poliwag [170.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Squirtle [100.0 HP]
# Opponent Active: Poliwag [130.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Squirtle [15.0 HP]
# Opponent Active: Poliwag [70.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Magikarp [500.0 HP]
# Opponent Active: Poliwag [10.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Magikarp [400.0 HP]
# Opponent Active: Rattata [500.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Magikarp [320.0 HP]
# Opponent Active: Rattata [410.0 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Magikarp [290.0 HP]
# Opponent Active: Rattata [320.0 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Magikarp [230.0 HP]
# Opponent Active: Rattata [320.0 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Magikarp [170.0 HP]
# Opponent Active: Rattata [230.0 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Magikarp [110.0 HP]
# Opponent Active: Rattata [140.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Magikarp [70.0 HP]
# Opponent Active: Rattata [50.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Oddish [500.0 HP]
# Opponent Active: Rattata [10.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Oddish [350.0 HP]
# Opponent Active: Charmander [500.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Oddish [310.0 HP]
# Opponent Active: Charmander [405.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Oddish [230.0 HP]
# Opponent Active: Charmander [395.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Oddish [190.0 HP]
# Opponent Active: Charmander [300.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Oddish [40.0 HP]
# Opponent Active: Charmander [290.0 HP]
# ----------------------------------------
# Step: 23
# Agent Active: Vulpix [500.0 HP]
# Opponent Active: Charmander [250.0 HP]
# ----------------------------------------
# Step: 24
# Agent Active: Vulpix [445.0 HP]
# Opponent Active: Charmander [200.0 HP]
# ----------------------------------------
# Step: 25
# Agent Active: Vulpix [400.0 HP]
# Opponent Active: Charmander [150.0 HP]
# ----------------------------------------
# Step: 26
# Agent Active: Vulpix [360.0 HP]
# Opponent Active: Charmander [120.0 HP]
# ----------------------------------------
# Step: 27
# Agent Active: Vulpix [320.0 HP]
# Opponent Active: Charmander [90.0 HP]
# ----------------------------------------
# Step: 28
# Agent Active: Vulpix [282.5 HP]
# Opponent Active: Charmander [70.0 HP]
# ----------------------------------------
# Step: 29
# Agent Active: Vulpix [232.5 HP]
# Opponent Active: Charmander [50.0 HP]
# ----------------------------------------
# Step: 30
# Agent Active: Vulpix [152.5 HP]
# Opponent Active: Vulpix [500.0 HP]
# ----------------------------------------
# Test Episode 5 finished with total reward: 7685.17
# Step: 1
# Agent Active: Squirtle [360.0 HP]
# Opponent Active: Electrike [440.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Squirtle [305.0 HP]
# Opponent Active: Electrike [380.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Squirtle [145.0 HP]
# Opponent Active: Electrike [330.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Squirtle [15.0 HP]
# Opponent Active: Electrike [330.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Electrike [500.0 HP]
# Opponent Active: Electrike [330.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Electrike [467.5 HP]
# Opponent Active: Electrike [265.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Electrike [407.5 HP]
# Opponent Active: Electrike [225.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Electrike [367.5 HP]
# Opponent Active: Electrike [195.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Electrike [327.5 HP]
# Opponent Active: Electrike [155.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Electrike [295.0 HP]
# Opponent Active: Electrike [115.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Electrike [230.0 HP]
# Opponent Active: Electrike [85.0 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Electrike [185.0 HP]
# Opponent Active: Electrike [85.0 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Electrike [140.0 HP]
# Opponent Active: Electrike [45.0 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Electrike [75.0 HP]
# Opponent Active: Electrike [15.0 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Electrike [20.0 HP]
# Opponent Active: Electrike [15.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Poliwag [500.0 HP]
# Opponent Active: Bulbasaur [500.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Poliwag [350.0 HP]
# Opponent Active: Bulbasaur [415.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Poliwag [200.0 HP]
# Opponent Active: Bulbasaur [400.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Poliwag [150.0 HP]
# Opponent Active: Bulbasaur [385.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Magikarp [500.0 HP]
# Opponent Active: Bulbasaur [300.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Magikarp [260.0 HP]
# Opponent Active: Bulbasaur [260.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Magikarp [140.0 HP]
# Opponent Active: Bulbasaur [205.0 HP]
# ----------------------------------------
# Step: 23
# Agent Active: Magikarp [20.0 HP]
# Opponent Active: Bulbasaur [165.0 HP]
# ----------------------------------------
# Step: 24
# Agent Active: Magikarp [-140.0 HP]
# Opponent Active: Bulbasaur [110.0 HP]
# ----------------------------------------
# Test Episode 6 finished with total reward: 4464.01
# Step: 1
# Agent Active: Pidgey [450.0 HP]
# Opponent Active: Magnemite [460.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Pidgey [395.0 HP]
# Opponent Active: Magnemite [420.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Pidgey [255.0 HP]
# Opponent Active: Magnemite [380.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Pidgey [5.0 HP]
# Opponent Active: Magnemite [340.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Pidgey [5.0 HP]
# Opponent Active: Magnemite [340.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Charmander [420.0 HP]
# Opponent Active: Magnemite [340.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Charmander [340.0 HP]
# Opponent Active: Magnemite [280.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Charmander [230.0 HP]
# Opponent Active: Magnemite [220.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Charmander [90.0 HP]
# Opponent Active: Magnemite [130.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Charmander [50.0 HP]
# Opponent Active: Magnemite [40.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Charmander [12.5 HP]
# Opponent Active: Magmar [500.0 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Cubone [500.0 HP]
# Opponent Active: Magmar [440.0 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Cubone [350.0 HP]
# Opponent Active: Magmar [370.0 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Cubone [240.0 HP]
# Opponent Active: Magmar [350.0 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Cubone [120.0 HP]
# Opponent Active: Magmar [330.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Cubone [25.0 HP]
# Opponent Active: Magmar [265.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Pidgey [5.0 HP]
# Opponent Active: Magmar [195.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Poliwag [500.0 HP]
# Opponent Active: Magmar [155.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Poliwag [445.0 HP]
# Opponent Active: Magmar [70.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Poliwag [205.0 HP]
# Opponent Active: Chikorita [500.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Poliwag [55.0 HP]
# Opponent Active: Chikorita [485.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Poliwag [-5.0 HP]
# Opponent Active: Chikorita [470.0 HP]
# ----------------------------------------
# Test Episode 7 finished with total reward: 5271.52
# Step: 1
# Agent Active: Magmar [400.0 HP]
# Opponent Active: Sandshrew [410.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Magmar [325.0 HP]
# Opponent Active: Sandshrew [320.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Magmar [245.0 HP]
# Opponent Active: Sandshrew [230.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Magmar [215.0 HP]
# Opponent Active: Sandshrew [155.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Magmar [135.0 HP]
# Opponent Active: Sandshrew [80.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Magmar [70.0 HP]
# Opponent Active: Charmander [500.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Magmar [30.0 HP]
# Opponent Active: Charmander [455.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Tropius [500.0 HP]
# Opponent Active: Charmander [417.5 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Tropius [420.0 HP]
# Opponent Active: Charmander [347.5 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Tropius [370.0 HP]
# Opponent Active: Charmander [282.5 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Tropius [300.0 HP]
# Opponent Active: Charmander [212.5 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Tropius [250.0 HP]
# Opponent Active: Charmander [147.5 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Tropius [50.0 HP]
# Opponent Active: Charmander [82.5 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Growlithe [500.0 HP]
# Opponent Active: Charmander [17.5 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Growlithe [462.5 HP]
# Opponent Active: Chikorita [500.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Growlithe [435.0 HP]
# Opponent Active: Chikorita [440.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Growlithe [350.0 HP]
# Opponent Active: Chikorita [320.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Growlithe [322.5 HP]
# Opponent Active: Chikorita [200.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Growlithe [277.5 HP]
# Opponent Active: Chikorita [120.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Growlithe [222.5 HP]
# Opponent Active: Poliwag [500.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Growlithe [137.5 HP]
# Opponent Active: Poliwag [470.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Growlithe [37.5 HP]
# Opponent Active: Poliwag [450.0 HP]
# ----------------------------------------
# Step: 23
# Agent Active: Growlithe [37.5 HP]
# Opponent Active: Poliwag [417.5 HP]
# ----------------------------------------
# Step: 24
# Agent Active: Growlithe [37.5 HP]
# Opponent Active: Poliwag [385.0 HP]
# ----------------------------------------
# Step: 25
# Agent Active: Meowth [500.0 HP]
# Opponent Active: Poliwag [352.5 HP]
# ----------------------------------------
# Step: 26
# Agent Active: Meowth [430.0 HP]
# Opponent Active: Poliwag [312.5 HP]
# ----------------------------------------
# Step: 27
# Agent Active: Meowth [345.0 HP]
# Opponent Active: Poliwag [252.5 HP]
# ----------------------------------------
# Step: 28
# Agent Active: Meowth [255.0 HP]
# Opponent Active: Poliwag [192.5 HP]
# ----------------------------------------
# Step: 29
# Agent Active: Meowth [190.0 HP]
# Opponent Active: Poliwag [152.5 HP]
# ----------------------------------------
# Step: 30
# Agent Active: Meowth [120.0 HP]
# Opponent Active: Poliwag [112.5 HP]
# ----------------------------------------
# Test Episode 8 finished with total reward: 9549.98
# Step: 1
# Agent Active: Squirtle [470.0 HP]
# Opponent Active: Psyduck [440.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Squirtle [425.0 HP]
# Opponent Active: Psyduck [390.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Squirtle [345.0 HP]
# Opponent Active: Psyduck [340.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Squirtle [300.0 HP]
# Opponent Active: Psyduck [290.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Squirtle [220.0 HP]
# Opponent Active: Psyduck [250.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Squirtle [140.0 HP]
# Opponent Active: Psyduck [210.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Squirtle [122.0 HP]
# Opponent Active: Psyduck [150.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Squirtle [82.0 HP]
# Opponent Active: Psyduck [90.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Squirtle [37.0 HP]
# Opponent Active: Psyduck [30.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Rattata [500.0 HP]
# Opponent Active: Bulbasaur [500.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Rattata [380.0 HP]
# Opponent Active: Bulbasaur [380.0 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Rattata [300.0 HP]
# Opponent Active: Bulbasaur [260.0 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Rattata [210.0 HP]
# Opponent Active: Bulbasaur [140.0 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Rattata [60.0 HP]
# Opponent Active: Bulbasaur [100.0 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Magnemite [500.0 HP]
# Opponent Active: Bulbasaur [60.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Magnemite [420.0 HP]
# Opponent Active: Bulbasaur [20.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Magnemite [330.0 HP]
# Opponent Active: Tropius [500.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Magnemite [240.0 HP]
# Opponent Active: Tropius [472.5 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Magnemite [110.0 HP]
# Opponent Active: Tropius [445.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Geodude [500.0 HP]
# Opponent Active: Tropius [425.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Geodude [440.0 HP]
# Opponent Active: Tropius [385.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Geodude [350.0 HP]
# Opponent Active: Tropius [335.0 HP]
# ----------------------------------------
# Step: 23
# Agent Active: Geodude [300.0 HP]
# Opponent Active: Tropius [285.0 HP]
# ----------------------------------------
# Step: 24
# Agent Active: Geodude [225.0 HP]
# Opponent Active: Tropius [235.0 HP]
# ----------------------------------------
# Step: 25
# Agent Active: Geodude [125.0 HP]
# Opponent Active: Tropius [205.0 HP]
# ----------------------------------------
# Step: 26
# Agent Active: Geodude [40.0 HP]
# Opponent Active: Tropius [155.0 HP]
# ----------------------------------------
# Step: 27
# Agent Active: Geodude [-10.0 HP]
# Opponent Active: Tropius [125.0 HP]
# ----------------------------------------
# Test Episode 9 finished with total reward: 7074.99
# Step: 1
# Agent Active: Electrike [410.0 HP]
# Opponent Active: Growlithe [435.0 HP]
# ----------------------------------------
# Step: 2
# Agent Active: Electrike [280.0 HP]
# Opponent Active: Growlithe [370.0 HP]
# ----------------------------------------
# Step: 3
# Agent Active: Electrike [190.0 HP]
# Opponent Active: Growlithe [305.0 HP]
# ----------------------------------------
# Step: 4
# Agent Active: Electrike [60.0 HP]
# Opponent Active: Growlithe [240.0 HP]
# ----------------------------------------
# Step: 5
# Agent Active: Meowth [500.0 HP]
# Opponent Active: Growlithe [200.0 HP]
# ----------------------------------------
# Step: 6
# Agent Active: Meowth [370.0 HP]
# Opponent Active: Growlithe [140.0 HP]
# ----------------------------------------
# Step: 7
# Agent Active: Meowth [315.0 HP]
# Opponent Active: Growlithe [100.0 HP]
# ----------------------------------------
# Step: 8
# Agent Active: Meowth [260.0 HP]
# Opponent Active: Growlithe [40.0 HP]
# ----------------------------------------
# Step: 9
# Agent Active: Meowth [230.0 HP]
# Opponent Active: Pikachu [500.0 HP]
# ----------------------------------------
# Step: 10
# Agent Active: Meowth [150.0 HP]
# Opponent Active: Pikachu [500.0 HP]
# ----------------------------------------
# Step: 11
# Agent Active: Meowth [70.0 HP]
# Opponent Active: Pikachu [440.0 HP]
# ----------------------------------------
# Step: 12
# Agent Active: Meowth [30.0 HP]
# Opponent Active: Pikachu [380.0 HP]
# ----------------------------------------
# Step: 13
# Agent Active: Sentret [500.0 HP]
# Opponent Active: Pikachu [340.0 HP]
# ----------------------------------------
# Step: 14
# Agent Active: Sentret [450.0 HP]
# Opponent Active: Pikachu [300.0 HP]
# ----------------------------------------
# Step: 15
# Agent Active: Sentret [360.0 HP]
# Opponent Active: Pikachu [260.0 HP]
# ----------------------------------------
# Step: 16
# Agent Active: Sentret [295.0 HP]
# Opponent Active: Pikachu [242.0 HP]
# ----------------------------------------
# Step: 17
# Agent Active: Sentret [265.0 HP]
# Opponent Active: Pikachu [202.0 HP]
# ----------------------------------------
# Step: 18
# Agent Active: Sentret [200.0 HP]
# Opponent Active: Pikachu [202.0 HP]
# ----------------------------------------
# Step: 19
# Agent Active: Sentret [180.0 HP]
# Opponent Active: Pikachu [162.0 HP]
# ----------------------------------------
# Step: 20
# Agent Active: Sentret [100.0 HP]
# Opponent Active: Pikachu [122.0 HP]
# ----------------------------------------
# Step: 21
# Agent Active: Sentret [20.0 HP]
# Opponent Active: Pikachu [32.0 HP]
# ----------------------------------------
# Step: 22
# Agent Active: Sandshrew [500.0 HP]
# Opponent Active: Chikorita [500.0 HP]
# ----------------------------------------
# Step: 23
# Agent Active: Sandshrew [460.0 HP]
# Opponent Active: Chikorita [460.0 HP]
# ----------------------------------------
# Step: 24
# Agent Active: Sandshrew [410.0 HP]
# Opponent Active: Chikorita [410.0 HP]
# ----------------------------------------
# Step: 25
# Agent Active: Sandshrew [360.0 HP]
# Opponent Active: Chikorita [360.0 HP]
# ----------------------------------------
# Step: 26
# Agent Active: Sandshrew [305.0 HP]
# Opponent Active: Chikorita [310.0 HP]
# ----------------------------------------
# Step: 27
# Agent Active: Sandshrew [245.0 HP]
# Opponent Active: Chikorita [260.0 HP]
# ----------------------------------------
# Step: 28
# Agent Active: Sandshrew [190.0 HP]
# Opponent Active: Chikorita [245.0 HP]
# ----------------------------------------
# Step: 29
# Agent Active: Sandshrew [150.0 HP]
# Opponent Active: Chikorita [195.0 HP]
# ----------------------------------------
# Step: 30
# Agent Active: Sandshrew [20.0 HP]
# Opponent Active: Chikorita [155.0 HP]
# ----------------------------------------
# Test Episode 10 finished with total reward: 6850.89
# Test Win Rate: 100.00%
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-82113531a68b> in <cell line: 0>()
#     319
#     320 print(f"Test Win Rate: {(test_wins/test_episodes)*100:.2f}%")
# --> 321 e
#
# NameError: name 'e' is not defined
